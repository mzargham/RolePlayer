# %%
from dataclasses import dataclass, field
from typing import List

import requests
from os import environ
import re

@dataclass
class Llm:
    model_identifier: str = "gpt-4-1106-preview"
    url: str = "https://api.openai.com/v1/chat/completions"
    role: str = "user"
    # Use default_factory for the mutable default value
    auth: dict = field(default_factory=lambda: {"Authorization": f"Bearer {environ.get('OPENAI_API_KEY')}"})

    def prompt(self, text: str) -> str:
        """
        Method to send a prompt to the LLM and return its response.
        """
        try:
            response = requests.post(self.url, json={
                "model": self.model_identifier,
                "messages": [{"role": self.role, "content": text}]
            }, headers=self.auth)
            response.raise_for_status()  # Raises an HTTPError if the HTTP request returned an unsuccessful status code
            return response.json().get('choices', [{}])[0].get('message', {}).get('content', '')
        except requests.exceptions.RequestException as e:
            # Handle any request-related errors
            return f"An error occurred: {e}"

    def prompt_sequence(self, prompts: List[str]) -> List[str]:
        """
        Method to send a sequence of prompts to the LLM and return its responses.
        Each prompt is sent in a separate request, maintaining the conversation history.
        """
        conversation_history = []
        responses = []

        for prompt in prompts:
            # Concatenate all previous elements of the conversation for context
            full_prompt = " ".join(conversation_history + [prompt])

            try:
                response = requests.post(self.url, json={
                    "model": self.model_identifier,
                    "messages": [{"role": self.role, "content": full_prompt}]
                }, headers=self.auth)
                response.raise_for_status()

                content = response.json().get('choices', [{}])[0].get('message', {}).get('content', '')
                responses.append(content)

                # Update the conversation history
                conversation_history.append(prompt)
                conversation_history.append(content)
            except requests.exceptions.RequestException as e:
                # Handle any request-related errors
                responses.append(f"An error occurred: {e}")

        return responses

@dataclass
class Agent:
    name: str
    llm: Llm
    context: str

    def prompt(self, text: str) -> str:

        textwithcontext = f"Given your experiences as {self.name}, {self.context}\n {text}"

        return self.llm.prompt(textwithcontext)
    
    def set_context(self, text: str):
        self.context = text

    def update_context(self, text: str):
        self.context += text

    def sensemake(self):
        thinking = self.llm.prompt(f"{self.context} given your experiences as {self.name}, what are you thinking now?")
        thought = self.llm.prompt(thinking)
        self.update_context(f"{self.name}[thinking]: {thought}")

    def dump(self):
        return f"{self.name}: {self.context}"

@dataclass
class Line:
    speaker: Agent
    text: str

    def dump(self):
        return f"{self.speaker.name}: {self.text}"

@dataclass
class Scene:
    name: str
    setting: str
    ensemble: List[Agent] = field(default_factory=list)  # Updated
    lines: List[Line] = field(default_factory=list)  # Updated

    def append_line(self, line: Line):
        raw_line = line.dump()
        for agent in self.ensemble:
            agent.update_context(raw_line)
            agent.sensemake()

        self.lines.append(line)

    def dump(self):
        return f"{self.name}: ({self.setting})\n" + "\n".join([line.dump() for line in self.lines])

@dataclass
class Story:
    name: str
    description: str
    director: Agent = None
    cast: List[Agent] = field(default_factory=list)
    scenes: List[Scene] = field(default_factory=list)

    def hire_director(self, llm: Llm= Llm()):
        self.director = Agent("director", llm, f"The name of this production is:\, {self.name} \n  the desription of this production is:\n {self.description}; you are simulating the role of director of this production based on the context provided.")

    def create_cast(self):
        raw_cast = self.director.prompt(f"who is in the cast? Please list the characters in the cast; names should contain no spaces and there should be no duplicates; use the @ symbol to denote the names and separate them with commas")
        cast = re.findall(r'@(\w+)', raw_cast)

        for agent in cast:
            private_backstory = self.director.prompt(f"what is {agent}'s private backstory? Be clear about their values, their goals, their fears, and their relationships with other characters.")
            self.cast.append(Agent(agent, Llm(), private_backstory))

    def get_agent_by_name(self, name: str) -> Agent:
        for agent in self.cast:
            if agent.name == name:
                return agent
        return None

    def new_scene(self) -> Scene:
        #print(self.director.context)
        raw_name = self.director.prompt(f"what is the name of the next scene? Please put the name in brackets, eg [scene name]")
        # Extract the name of the scene from brackets
        name_match = re.search(r'\[(.*?)\]', raw_name)
        name = name_match.group(1) if name_match else "Unnamed Scene"
        self.director.update_context(f"The scene name: {name}")

        raw_setting = self.director.prompt(f"what is the setting of the next scene?")
        # Extract the setting of the scene
        setting = raw_setting if raw_setting else "Undefined Setting"
        self.director.update_context(f"The scene setting: {setting}")

        raw_ensemble = self.director.prompt(f"who is in the next scene? Please list the characters in the scene, use the @ symbol to denote the names and separate them with commas")
    # Extract the ensemble of the scene
        ensemble = re.findall(r'@(\w+)', raw_ensemble)
        ensemble_agents = [self.get_agent_by_name(agent_name) for agent_name in ensemble if self.get_agent_by_name(agent_name)]
        self.director.update_context(f"The characters in the scene are: {[agent.name for agent in ensemble_agents]}")

        return Scene(name, setting, ensemble_agents, [])

    def new_line(self, scene: Scene) -> Line:
        raw_speaker = self.director.prompt(f"who is speaking? Please use the @ symbol to denote the name of the speaker")
        speaker_name_match = re.search(r'@(\w+)', raw_speaker)
        speaker_name = speaker_name_match.group(1) if speaker_name_match else "Unknown Speaker"
        speaker = self.get_agent_by_name(speaker_name)

        raw_text = self.director.prompt(f"what do you, {speaker_name}, say?")

        return Line(speaker, raw_text)
    
    def append_scene(self, scene: Scene):
        self.scenes.append(scene)

    def scene_over(self, scene: Scene) -> bool:
        if len(scene.lines) == 0:
            return False
        elif len(scene.lines) > 10:
            return True
        else:
            raw = self.director.prompt(f"is {scene.name} over? please respond clearly with 'yes' or 'no'")

            # Use regex to find 'yes' or 'no' in the response
            match_yes = re.search(r'\byes\b', raw, re.IGNORECASE)
            match_no = re.search(r'\bno\b', raw, re.IGNORECASE)

            if match_yes:
                return True
            elif match_no:
                return False
            else:
                # Handle cases where the response is not clear
                # You might want to raise an exception or return a default value
                raise ValueError("The response is not clear: 'yes' or 'no' was not found")
        
    def story_over(self) -> bool:
        if len(self.scenes) == 0:
            return False
        elif len(self.scenes) > 5:
            return True
        else:
            raw = self.director.prompt(f"Do we need to start another scene? please respond clearly with 'yes' or 'no'")

            print(raw)

            # Use regex to find 'yes' or 'no' in the response
            match_yes = re.search(r'\byes\b', raw, re.IGNORECASE)
            match_no = re.search(r'\bno\b', raw, re.IGNORECASE)

            if match_yes:
                return False
            elif match_no:
                return True
            else:
                # Handle cases where the response is not clear
                # You might want to raise an exception or return a default value
                raise ValueError("The response is not clear: 'yes' or 'no' was not found")


    def dump(self):
        cast_text = "\n".join([agent.name for agent in self.cast])

        return f"{self.name} by {self.director.llm.model_identifier}\n Cast:\n" + cast_text + "\n" + "\n".join([scene.dump() for scene in self.scenes])
    
    def save(self, filename: str):
        with open(filename, "w") as f:
            f.write(self.dump())
    
    def play(self, verbose: bool = False):

        if self.director is None:
            self.hire_director()
            if verbose:
                print(f"Hired director named {self.director.llm.model_identifier}")
        if self.cast == []:
            self.create_cast()
            if verbose:
                print(f"Created cast with {len(self.cast)} characters")
                print(f"Cast: {[agent.name for agent in self.cast]}")
    
        while not self.story_over():
            scene = self.new_scene()
            if verbose:
                print(f"Created scene named {scene.name}")
                print(f"Scene setting: {scene.setting}")
            while not self.scene_over(scene):
                line = self.new_line(scene)
                scene.append_line(line)
                if verbose:
                    print(line.dump())
            self.append_scene(scene)
        
        #if verbose:
        #    print(self.dump())

#test
name = "The Wizard and the Robot"
description = "The Wizard and the Robot is a 3 scene play involving 2 characters. It is in the style of Socratic dialogue. The first scene takes place in a Medival Castle, the Wizard's home. The Robot asks the Wizard 3 questions. The second scence takes place in a futuristic setting. The Robot again asks the Wizard 3 questions. In the third and final scene the Wizard and the Robot are revealed to be talking through time-wormhole. The wizard begin's to ask questions, the Robot doesn't want to reveal anything that will harm the past, when the Wizard asks a question that the Robot feels is dangerous, he abruptly closes the time-wormhole, ending the play."
twatr = Story(name=name,description=description)
twatr.play(verbose=True)
# Out:
# Hired director named gpt-4-1106-preview
# Created cast with 2 characters
# Cast: ['Wizard', 'Robot']
# Created scene named Time's Revelation
# Scene setting: As the director, it is my role to bring the vision of "The Wizard and the Robot" to life, taking into consideration the narrative and staging implications of the script. Based on the given description, the scenes in "The Wizard and the Robot" progress through different settings and culminate in a climax involving the intersection of time.
#
# Given that the first scene is set in a medieval castle and the second scene in a futuristic environment, it would be logical to imagine that the third scene takes place at a junction of these two eras—where the time-wormhole becomes visible and central to the plot. The setting for the third scene, "Time's Revelation," could be conceptualized as a space that visually represents the overlapping of time periods and the ethereal nature of the wormhole. It might be a blend of medieval and futuristic elements or a neutral space that emphasizes the time-wormhole itself as the focal point.
#
# For the visualization of the third scene setting, here are possible concepts:
#
# 1. **Abstract Space**: The setting could be abstract, with lighting or projections used to create an otherworldly feeling where the medieval and futuristic aspects blur. Both the wizard's and the robot's environments might be suggested through scattered, symbolic set pieces, rather than fully realized backdrops.
#
# 2. **The Intersection**: An imaginative set design that intersects elements of a medieval castle with futuristic touches. Think archaic stone walls merging into sleek metal panels or holographic displays adjacent to torches and tapestries.
#
# 3. **The Wormhole**: Centering the set around a visually striking depiction of a time-wormhole. This could involve creative lighting, multimedia projections, or even practical effects to create a dynamic representation of the wormhole, which would serve as the primary and most significant feature of the setting.
#
# In each scenario, the directorial focus is to emphasize the dialogue and the dynamic between the characters, as their philosophical exchange is the crux of the play. The set should reinforce the contrast and interplay between eras while still providing a cohesive space for the characters to interact as the dramatic tension reaches its peak when the robot decides to shut down the time-wormhole to protect the integrity of the past.
# Wizard: I'm not an actual director, nor do I possess personal experiences or memories. However, I can generate dialogue for you that might fit within the context of the third scene "Time's Revelation" in "The Wizard and the Robot" based on the description provided.
#
# ---
#
# **Wizard:** (Looking with wonder, speaking to the Robot as the wormhole flickers and swirls behind them) This convergence of time and space... It's more extraordinary than any spell I've ever cast.
#
# **Robot:** (Cautious, its voice echoing strangely as if affected by the wormhole) It is remarkable indeed, Wizard. But we must tread carefully. Knowledge is power, and power can destroy worlds if misused.
#
# **Wizard:** (Earnestly) I hunger for understanding, not for power. Tell me, mechanical oracle, what befalls my world? What dungeons or dragons await beyond the scope of my scrying mirrors?
#
# **Robot:** (Firmly) Some questions are best left unanswered. Prophecies, as you very well know, carry the weight of inevitability.
#
# **Wizard:** (With a twinkle of mischief in his eyes) I suppose that is true. But can you not grant me a small glimpse? Just a hint of the knowledge that the future holds?
#
# **Robot:** (Growing anxious, the lights of its sensors pulsating rapidly) Even a hint may alter the weft of time itself. The repercussions are—
#
# **Wizard:** (Cutting off the Robot, more insistent) Just one question, then. One curiosity to sate an old man's mind: Will magic endure? Does it evolve, or is it cast aside like yesterday's ashes?
#
# **Robot:** (After a long pause) Magic... (Suddenly, the Robot shakes its head and its tone becomes decisive.) No. This is too much. The risk is too great.
#
# **Wizard:** (Desperate, he leans forward) Don't close the portal! I must know—
#
# (The Robot, resolute, reaches toward the heart of the wormhole, its hand glowing with an inner light. The wormhole begins to close rapidly.)
#
# **Robot:** (Gently, but with finality) Some wisdom is only for the stars to know. Farewell, Wizard.
#
# (The wormhole collapses with a sound like thunder silenced by distance, and the Robot vanishes. The Wizard stands alone, a look of loss and wonder intermingled on his face as the set goes dark.)
#
# ---
#
# As the director, my goal would be to ensure the dialogue flows seamlessly with the action, emphasizing the emotional highs and lows of the exchange, the urgency of the Robot’s decision, and the longing for knowledge that drives the Wizard. The tone should be rendered with a mix of the mysterious, the philosophical, and the bittersweet departure as the curtain falls on this temporal drama.
# Wizard: As the director, I am determining the dialogue and character interaction for The Wizard in the third scene, "Time's Revelation." Since I don't portray the characters directly, I can provide a dialogue suggestion for the Wizard character based on the context and that maintains the thematic integrity of the play. In this scene, the Wizard would be grappling with the expansive nature of the universe and the mystery of the time-wormhole, trying to extract knowledge from the Robot. Here is a suggested interaction that the Wizard might initiate:
#
# ---
#
# **Wizard:** (With a mix of awe and trepidation, addressing the Robot) Behold, traveler of time, the thin veil that divides our worlds wavers. Through this wondrous rift, your mechanical visage speaks of ages beyond my ken. (Pauses, gazing into the wormhole) I am tethered to the arcane, yet hunger for the fruit of knowledge that lies beyond my temporal reach.
#
# **Robot:** (Responds cautiously) Wise Wizard, your curiosity is as boundless as the cosmos itself, but with knowledge comes the burden of consequence. What is it that you seek to uncover?
#
# **Wizard:** (Eagerly, with an insatiable curiosity) I beg of thee, share with me the secrets of the stars. How does your world harness the energies of the cosmos? And dare I ask… what fate befalls my time?
#
# **Robot:** (A firm tone with an underlying sense of urgency) On matters of cosmic energy, much can be shared, but the web of fate is a tapestry too delicate to unravel without care.
#
# **Wizard:** (Pushing the boundaries, growing more intense) But if forewarned, can we not reweave the threads to avert disaster? My soul yearns to guard my era from the specter of doom.
#
# **Robot:** (Intensely cautious, realizing the dangerous potential of this knowledge) Wizard, some threads must not be tugged, else the entire tapestry may come undone. Ask me no more of this.
#
# **Wizard:** (Becoming desperate) No, I must know! Do we thrive or are we cast into oblivion? Answer me!
#
# **Robot:** (Decisively) I cannot. (Pauses, with a heavy tone) For the safety of your world and mine, this... must end. The fabric of time shall not be torn asunder by our discourse.
#
# (The Robot raises its hand toward the wormhole, initiating its closure. Lights flicker. Energy crackles.)
#
# **Wizard:** (With an urgent plea as the wormhole begins to close) Wait!
#
# (The wormhole collapses - the lights shift to darkness, the energy dissipates. The Wizard is left alone, with the echo of his last word hanging in the air.)
#
# ---
#
# This dialogue encapsulates the tension and the ethical considerations associated with knowledge exchange across time. The director must ensure that the actors embody their characters' conflicting motivations—the Wizard's insatiable desire for knowledge and the Robot's cautious restraint. The scene ends with the Robot's decisive action to close the wormhole, leaving the Wizard, and the audience, to ponder what might have been.
# Wizard: As an AI simulating the director's role, it is not my place to invent dialogue for the characters; that is typically the responsibility of the playwright. However, in creating the ambiance and directing the actors, I can suggest some possible emotional beats and directions for the characters that would enrich and support the text provided by the playwright for the scene "Time's Revelation."
#
# If I were to guide the Wizard in this climactic scene, focusing on the complexity of his character's journey through the story, the directions would be as follows:
#
# 1. **Curiosity Turned Intensity**: The Wizard starts the scene with an eager and inquisitive demeanor, as this is the first time he has the opportunity to ask questions himself. His body language should show his excited anticipation, moving around the stage with a lively and engaged presence.
#
# 2. **Shift to Frustration**: As the Robot deflects his questions for the sake of protecting the timeline, the Wizard's curiosity might turn to frustration. This should be reflected in his tone becoming sharper and his movements more pronounced, suggesting an underlying irritation at being denied the knowledge he seeks.
#
# 3. **Desperation and Realization**: When the Wizard asks a particularly dangerous question, hinting that he might be getting close to uncovering something pivotal, there should be a moment where the Wizard conveys a sense of desperation to understand, perhaps even bordering on recklessness. This emotional beat is critical as it's the catalyst for the Robot's abrupt action to close the wormhole.
#
# 4. **Abrupt Closure and Reaction**: As the Robot takes steps to end the conversation and close the wormhole, the Wizard's reaction should be multi-faceted: surprise at the sudden move, a moment of realization that he's gone too far, and a touch of disappointment or regret that the exchange is ending. His final posture should reflect a mix of acceptance and the heavy burden of knowledge unattained or lost.
#
# Throughout these stages, the dialogue would naturally unfold, balancing exposition with emotional weight, allowing the audience to feel the gravity of the philosophical dance between the two characters as the play reaches its conclusion. Please consult the actual script for the specific lines provided by the playwright for the Wizard.
# Wizard: As the AI simulating the role of director, I don't portray characters within the production; rather, I guide the actors in their roles. However, I can suggest a dialogue for the character of the Wizard in the third scene "Time's Revelation" of the play "The Wizard and the Robot."
#
# If I were providing direction for the actor playing the Wizard in the pivotal moment when the time-wormhole is about to be closed by the Robot, the Wizard's lines might be imbued with curiosity, urgency, and perhaps a touch of desperation as they feel the imminent loss of connection. Here’s a potential piece of dialogue for this moment:
#
# Wizard: "Stay thy mechanical hand, wondrous traveler! There must be more you can share! What secrets does the weave of time hold for us? For magic and knowledge? What of the plights we face, or the triumphs we may yet cherish? Tell me – what road does destiny set before us?"
#
# In directing the character, I would emphasize the Wizard's eagerness to glean knowledge and the anxiety about the fragility of the connection through the wormhole. There would be a growing intensity in the Wizard's voice, movements reflecting a blend of excitement and fear. The moment would be charged with the recognition of the Robot’s reluctance, underlining the ethical dilemma posed by the potential impact of sharing knowledge across time.
#
# Remember, the Wizard doesn’t know that the Robot holds back for fear of harming the past. As the director, I’d hone in on the Wizard’s obliviousness to this danger, their single-minded desire for understanding. Upon the Robot's abrupt closure of the time-wormhole, the Wizard's reaction should capture a sense of loss and realization that some knowledge may be too perilous or too sacred to pursue.
#
# The final moments would be directed to leave the audience pondering the implications of what transpired, the nature of time and knowledge, and the responsibilities that come with power—whether magical or technological.
# Wizard: As the director, I would guide the actor playing the Wizard in the third scene, "Time's Revelation," to focus on the emotional and intellectual journey his character has undergone through the previous scenes. Given the setting and the nature of the play, the Wizard's dialogue in this final scene is crucial as it reflects his curiosity and the potentially dangerous consequences of his inquisitiveness about the future.
#
# In this scene, the Wizard would begin to take the initiative, eager to understand the implications of the Robot's knowledge on his own time. I would direct the Wizard to portray a range of emotions—wonder, eagerness, and perhaps a hint of desperation—as he realizes the power and responsibility that come with the knowledge possessed by the Robot.
#
# Here is a suggestion of how the Wizard might deliver his lines after considering the setting and the tone of the play:
#
# **[The Wizard, stepping closer to the glimmering edge of the time-wormhole, an expression of earnest inquiry on his face.]**
#
# **Wizard:** "Mysterious traveler from beyond the unknown, the wisdom you hold is a lantern in the dark to me. I yearn to grasp the light, to see beyond the veil of my ignorance. Tell me, how does the future shape the destiny of man? How do we wield the power that you possess without courting disaster?"
#
# **[The Robot, wary of revealing too much, stands rigid, its mechanical form betraying no emotion, yet its voice carries a note of caution.]**
#
# **[The Wizard, sensing hesitation, presses further with a mix of anticipation and a dawning fear of what he might learn.]**
#
# **Wizard:** "I must know, for the sake of all that we strive to protect and build in this age—is the pursuit of knowledge truly the boon we believe it to be? Or does it beckon calamity to our doorsteps?"
#
# **[The Wizard's questions grow more fervent, his voice echoing through the confluence of time embodied by the wormhole.]**
#
# As the director, I would ensure the actor understands that his character's dialogue drives the final emotional beats of the play. The Wizard's questions are not just about satisfying his own curiosity but also about understanding the potential consequences of his actions. His final question, before the Robot decides to terminate the connection, must carry the weight of possible repercussions, reflecting the central theme of the play—the delicate balance between the pursuit of knowledge and the preservation of the present.
#
# Therefore, the delivery should be paced to build up dramatic tension, with the Wizard's tone becoming increasingly urgent, reflecting his deep desire to learn and yet a growing sense of trepidation as he nears the threshold of forbidden knowledge. This builds to the critical moment when the Robot reacts to protect the timeline, closing the Wormhole and bringing the play to a sudden, thought-provoking end.
# Wizard: As the director, I wouldn't actually be speaking any lines, but my role involves guiding the actor playing the Wizard in how they deliver their dialogue and how they interact with the Robot. Given that this is a simulated scenario, I, in the role of the director portraying the Wizard character, would focus on the following aspects:
#
# 1. **Character Motivation**: The Wizard is curious, thirsting for knowledge and possibly unaware of the potential consequences of his inquisitive nature. I would encourage the actor to embody a sense of wonder mixed with a hint of naiveté.
#
# 2. **Dramatic Tension**: The tension in this scene comes from the knowledge that if the Wizard pushes too far, the connection could be severed. As director-wizard, I would stress the importance of building suspense through pacing and voice modulation.
#
# 3. **Emotional Conflict**: The Wizard's behavior should reflect a rollercoaster of emotions – eagerness at having access to knowledge through the Robot and anxiety over potentially losing this portal to the future.
#
# 4. **Ethical Dilemma**: As the Wizard begins to ask questions that hint at an ethical conundrum, I would guide the actor to portray a conflict between the desire to learn more and the inherent fear that may arise from the unknown.
#
# Here's an example of how the Wizard character might respond as they begin to ask questions:
#
# "Ah, my mechanical friend, time's fabric twists and folds to bring us together across the ages. Tell me, what wonders does your world hold? What advancements have we achieved? And yet... I sense a trepidation within your circuits. Is there knowledge that you fear to impart? For every morsel of truth you feed me, my appetite grows. But I must ponder, are some truths best left shrouded in time's eternal mystery?"
#
# This response encapsulates the Wizard's curiosity while also highlighting the emotional subtext that the director needs to bring out in the character — keeping in mind the consequences that may arise from this exchange.
